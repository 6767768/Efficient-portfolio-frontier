# %%
import pandas as pd
import csv
import datetime
import numpy as np
from statsmodels.api import OLS
import matplotlib.pyplot as plt
import os
import re
import statsmodels.api as sm
from scipy import stats

# %%
temp_file='G:/test/test.csv'
path_return='G:/test/path_return.csv'

# %%
if (os.path.exists(path_return)):
    os.remove(path_return)
    print("原文件删除成功")
else:
    print("原文件不存在，创建新的原文件")
# Out:
# 原文件删除成功

# %%
# def process_csv(path,docket,index):
#     if (os.path.exists(path)==False):
#         with open(path,'w') as f:
#             f.write('monthly rate input\n')
# #path_return为净值的csv

#     cache=pd.DataFrame(docket,columns=[index])
#     temp=pd.read_csv(path)
#     temp=pd.concat([temp,cache],axis=1)
#     messup(temp,path)
#     temp.to_csv(path,index=False,header=True)
#     print(index+'储存完成')
#     print('***************************')

# def process_monthly_data(df,path):
#     time='time'
#     date=len(df.loc[:,[time]])-1
#     index=df.columns.values[1]
#     #处理股指的月收益率
#     docket=[]

#     value=df.loc[[0],[index]].values[0][0]
#     temp=(datetime.datetime.strptime(df.loc[[0],[time]].values[0][0],'%Y-%m-%d')).month
#     for i in range(0,date,1):

#         if (temp!=(datetime.datetime.strptime(df.loc[[i],[time]].values[0][0],'%Y-%m-%d')).month):
#             docket.append((df.loc[[i],[index]].values[0][0]-value)/value)
#             value=df.loc[[i],[index]].values[0][0]

#         temp=(datetime.datetime.strptime(df.loc[[i],[time]].values[0][0],'%Y-%m-%d')).month

#     docket.append((df.loc[[date],[index]].values[0][0]-value)/value) #加上最后一天的月收益率
#     print("********************************")
#     print(index+'计算完成')  
#     process_csv(path,docket,index)
    
# def messup(df,path):
#     for i in range(5):
#         if 'Unnamed: 0' in df.columns.values:
#             df.drop(columns='Unnamed: 0',axis=1,inplace=True)
#             print('已删除多余的Unnamed: 0列')
#         elif 'Unnamed: 0.1' in df.columns.values:
#             df.drop(columns='Unnamed: 0.1',axis=1,inplace=True)
#             print('已删除多余的Unnamed: 0.1列')
#         elif 'Unnamed: 0.1.1' in df.columns.values:
#             df.drop(columns='Unnamed: 0.1.1',axis=1,inplace=True)
#             print('已删除多余的Unnamed: 0.1.1列')
#         elif 'Unnamed: 0.1.1.1' in df.columns.values:
#             df.drop(columns='Unnamed: 0.1.1.1',axis=1,inplace=True)
#             print('已删除多余的Unnamed: 0.1.1.1列')
#         elif 'Unnamed: 0.1.1.1.1' in df.columns.values:
#             df.drop(columns='Unnamed: 0.1.1.1.1',axis=1,inplace=True)
#             print('已删除多余的Unnamed: 0.1.1.1.1列')
#     if (os.path.exists(path)):
#         os.remove(path)

# %%
def process_csv(path,docket,index):
    if (os.path.exists(path)==False):
        with open(path,'w') as f:
            f.write('monthly rate input\n')
#path_return为净值的csv

    cache=pd.DataFrame(docket,columns=[index])
    temp=pd.read_csv(path)
    temp=pd.concat([temp,cache],axis=1)
    messup(temp,path)
    temp.to_csv(path,index=False,header=True)
    print(index+'储存完成')
    print('***************************')

def process_monthly_data(df,path):
    time='time'
    date=len(df.loc[:,[time]])-1
    index=df.columns.values[1]
    #处理股指的月收益率
    docket=[]

    value=df.loc[[0],[index]].values[0][0]
    temp=(datetime.datetime.strptime(df.loc[[0],[time]].values[0][0],'%Y-%m-%d')).month
    for i in range(0,date,1):

        if (temp!=(datetime.datetime.strptime(df.loc[[i],[time]].values[0][0],'%Y-%m-%d')).month):
            docket.append((df.loc[[i],[index]].values[0][0]-value)/value)
            value=df.loc[[i],[index]].values[0][0]

        temp=(datetime.datetime.strptime(df.loc[[i],[time]].values[0][0],'%Y-%m-%d')).month

    docket.append((df.loc[[date],[index]].values[0][0]-value)/value) #加上最后一天的月收益率
    docket_0=[(i-0.015) for i in docket]
    print("********************************")
    print(index+'计算完成')  
    process_csv(path,docket_0,index)
    
def messup(df,path):
    for i in range(5):
        if 'Unnamed: 0' in df.columns.values:
            df.drop(columns='Unnamed: 0',axis=1,inplace=True)
            print('已删除多余的Unnamed: 0列')
        elif 'Unnamed: 0.1' in df.columns.values:
            df.drop(columns='Unnamed: 0.1',axis=1,inplace=True)
            print('已删除多余的Unnamed: 0.1列')
        elif 'Unnamed: 0.1.1' in df.columns.values:
            df.drop(columns='Unnamed: 0.1.1',axis=1,inplace=True)
            print('已删除多余的Unnamed: 0.1.1列')
        elif 'Unnamed: 0.1.1.1' in df.columns.values:
            df.drop(columns='Unnamed: 0.1.1.1',axis=1,inplace=True)
            print('已删除多余的Unnamed: 0.1.1.1列')
        elif 'Unnamed: 0.1.1.1.1' in df.columns.values:
            df.drop(columns='Unnamed: 0.1.1.1.1',axis=1,inplace=True)
            print('已删除多余的Unnamed: 0.1.1.1.1列')
    if (os.path.exists(path)):
        os.remove(path)

# %%
stock_index='000016.XSHG'

# %%
get_index_stocks(stock_index)
# Out:
# ['600000.XSHG',
#  '600016.XSHG',
#  '600019.XSHG',
#  '600028.XSHG',
#  '600029.XSHG',
#  '600030.XSHG',
#  '600031.XSHG',
#  '600036.XSHG',
#  '600048.XSHG',
#  '600050.XSHG',
#  '600104.XSHG',
#  '600196.XSHG',
#  '600276.XSHG',
#  '600309.XSHG',
#  '600340.XSHG',
#  '600519.XSHG',
#  '600585.XSHG',
#  '600690.XSHG',
#  '600703.XSHG',
#  '600837.XSHG',
#  '600887.XSHG',
#  '601066.XSHG',
#  '601088.XSHG',
#  '601111.XSHG',
#  '601138.XSHG',
#  '601166.XSHG',
#  '601186.XSHG',
#  '601211.XSHG',
#  '601229.XSHG',
#  '601288.XSHG',
#  '601318.XSHG',
#  '601319.XSHG',
#  '601328.XSHG',
#  '601336.XSHG',
#  '601390.XSHG',
#  '601398.XSHG',
#  '601601.XSHG',
#  '601628.XSHG',
#  '601668.XSHG',
#  '601688.XSHG',
#  '601766.XSHG',
#  '601800.XSHG',
#  '601818.XSHG',
#  '601857.XSHG',
#  '601888.XSHG',
#  '601939.XSHG',
#  '601988.XSHG',
#  '601989.XSHG',
#  '603259.XSHG',
#  '603993.XSHG']

# %%
stock=['601229.XSHG',
 '600276.XSHG',
 '600585.XSHG',
 '600028.XSHG',
 '601186.XSHG',
 '600036.XSHG',
 '601688.XSHG',
 '601818.XSHG',
 '601328.XSHG',
 '601288.XSHG',
 '600031.XSHG',
 '601766.XSHG',
 '601800.XSHG',
 '601857.XSHG',
 '601888.XSHG',
 '601939.XSHG',
 '601988.XSHG',
 '601989.XSHG',
 '601601.XSHG',
 '603993.XSHG']

# %%
get_extras('is_st',stock , start_date='2018-01-01', end_date='2018-12-31', df=True)
# Out:
#             601229.XSHG  600276.XSHG     ...       601601.XSHG  603993.XSHG
# 2018-01-02        False        False     ...             False        False
# 2018-01-03        False        False     ...             False        False
# 2018-01-04        False        False     ...             False        False
# 2018-01-05        False        False     ...             False        False
# 2018-01-08        False        False     ...             False        False
# 2018-01-09        False        False     ...             False        False
# 2018-01-10        False        False     ...             False        False
# 2018-01-11        False        False     ...             False        False
# 2018-01-12        False        False     ...             False        False
# 2018-01-15        False        False     ...             False        False
# 2018-01-16        False        False     ...             False        False
# ...

# %%
for i in stock: 
    info=get_price(i, start_date='2018-01-01', end_date='2018-12-31', frequency='daily', fields=None, skip_paused=False, fq='pre')
    info=info.loc[:,['open']]
    
    if (os.path.exists(temp_file)):
        os.remove(temp_file)
        print("原文件删除成功")
    else:
        print("原文件不存在，创建新的原文件")

    info.to_csv(temp_file)  
    df=pd.read_csv(temp_file)

    df=df.rename(columns={'Unnamed: 0':'time','open':i})
    
    index=df.columns.values[1]
    process_monthly_data(df,path_return)
# Out:
# ---------------------------------------------------------------------------
# DownloadFailedError                       Traceback (most recent call last)
# <ipython-input-10-0af356c16f0a> in <module>
#       1
#       2 for i in stock:
# ----> 3     info=get_price(i, start_date='2018-01-01', end_date='2018-12-31', frequency='daily', fields=None, skip_paused=False, fq='pre')
#       4     info=info.loc[:,['open']]
#       5
#
# F:\JoinQuant-Desktop-Py3\Python\lib\site-packages\jqresearch\api.cp36-win_amd64.pyd in jqresearch.api.get_price()
#
# F:\JoinQuant-Desktop-Py3\Python\lib\site-packages\jqdata\apis\data.cp36-win_amd64.pyd in jqdata.apis.data.get_price()
#
# F:\JoinQuant-Desktop-Py3\Python\lib\site-packages\jqdata\apis\datalib.cp36-win_amd64.pyd in jqdata.apis.datalib.get_price_daily_single()
#
# F:\JoinQuant-Desktop-Py3\Python\lib\site-packages\jqdata\apis\datalib.cp36-win_amd64.pyd in jqdata.apis.datalib.fetch_daily_data()
#
# ...

# %%
info=get_price(stock_index, start_date='2018-01-01', end_date='2018-12-31', frequency='daily', fields=None, skip_paused=True, fq='pre')
info=info.loc[:,['open']]
if (os.path.exists(temp_file)):
    os.remove(temp_file)
    print("原文件删除成功")
else:
    print("原文件不存在，创建新的原文件")

info.to_csv(temp_file)  
df=pd.read_csv(temp_file)

df=df.rename(columns={'Unnamed: 0':'time','open':'XSHG'})

process_monthly_data(df,path_return)
# Out:
# 原文件删除成功
# ********************************
# XSHG计算完成
# XSHG储存完成
# ***************************
