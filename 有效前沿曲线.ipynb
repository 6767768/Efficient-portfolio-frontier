# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.optimize as sco

plt.style.use('fivethirtyeight')
np.random.seed(777)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
stock=['601229.XSHG',
 '600276.XSHG',
 '600585.XSHG',
 '600028.XSHG',
 '601186.XSHG',
 '600036.XSHG',
 '601688.XSHG',
 '601818.XSHG',
 '601328.XSHG',
 '601288.XSHG',
 '600031.XSHG',
 '601766.XSHG',
 '601800.XSHG',
 '601857.XSHG',
 '601888.XSHG',
 '601939.XSHG',
 '601988.XSHG',
 '601989.XSHG',
 '601601.XSHG',
 '603993.XSHG']

# %%
df=pd.DataFrame([])
for i in stock:
    info=get_price(i, start_date='2018-01-01', end_date='2018-12-31', frequency='daily', fields=None, skip_paused=False, fq='pre')
    info=info.loc[:,['open']]
    info=info.rename(columns={'open':i})
    df=pd.concat([info,df],axis=1)
# Out:
# ---------------------------------------------------------------------------
# DownloadFailedError                       Traceback (most recent call last)
# <ipython-input-4-3b51cc2d1955> in <module>
#       1 df=pd.DataFrame([])
#       2 for i in stock:
# ----> 3     info=get_price(i, start_date='2018-01-01', end_date='2018-12-31', frequency='daily', fields=None, skip_paused=False, fq='pre')
#       4     info=info.loc[:,['open']]
#       5     info=info.rename(columns={'open':i})
#
# F:\JoinQuant-Desktop-Py3\Python\lib\site-packages\jqresearch\api.cp36-win_amd64.pyd in jqresearch.api.get_price()
#
# F:\JoinQuant-Desktop-Py3\Python\lib\site-packages\jqdata\apis\data.cp36-win_amd64.pyd in jqdata.apis.data.get_price()
#
# F:\JoinQuant-Desktop-Py3\Python\lib\site-packages\jqdata\apis\datalib.cp36-win_amd64.pyd in jqdata.apis.datalib.get_price_daily_single()
#
# ...

# %%
#df=df.iloc[:,2:7]

# %%
wgt=len(df.columns)

# %%
plt.figure(figsize=(14, 7))
for c in df.columns.values:
    plt.plot(df.index, df[c], lw=1, alpha=0.8,label=c)
    plt.legend(loc='upper left', fontsize=12)
    plt.ylabel('price in $')

# %%
returns = df.pct_change()

plt.figure(figsize=(14, 7))
for c in returns.columns.values:
    plt.plot(returns.index, returns[c], lw=1, alpha=0.8,label=c)
    plt.legend(loc='upper right', fontsize=12)
    plt.ylabel('daily returns')

# %%
pd.DataFrame(mean_returns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-928c0a206295> in <module>
# ----> 1 pd.DataFrame(mean_returns)
#
# NameError: name 'mean_returns' is not defined

# %%
def portfolio_annualised_performance(weights, mean_returns, cov_matrix):
    returns = np.sum(mean_returns*weights ) *252
    std = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights))) * np.sqrt(252)
    return std, returns

def random_portfolios(num_portfolios, mean_returns, cov_matrix, risk_free_rate):
    results = np.zeros((3,num_portfolios))
    weights_record = []
    
#     1 # 603993.XSHG	-0.001921 
#     2 # 601601.XSHG	-0.001157
#     3 # 601989.XSHG	-0.001306
#     4 # 601988.XSHG	-0.000076
#     5 # 601939.XSHG	-0.000447
#     6 # 601888.XSHG	0.001788
#     7 # 601857.XSHG	-0.000293
#     8 # 601800.XSHG	-0.000187
#     9 # 601766.XSHG	-0.001133
#     10 # 600031.XSHG	-0.000084
#     11 # 601288.XSHG	0.000045
#     12 # 601328.XSHG	-0.000065
#     13 # 601818.XSHG	-0.000134
#     14 # 601688.XSHG	0.000018
#     15 # 600036.XSHG	-0.000287
#     16 # 601186.XSHG	0.000153
#     17 # 600028.XSHG	-0.000273
#     18 # 600585.XSHG	0.000429
#     19 # 600276.XSHG	0.000302
#     20 # 601229.XSHG	0.000529
    
    for i in range(0,10000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=np.random.random(1)[0]
        four=0
        five=0
        six=0
        seven=np.random.random(1)[0]
        eight=0
        nine=np.random.random(1)[0]
        ten=0
        eleven=np.random.random(1)[0]
        twelve=np.random.random(1)[0]
        thirteen=np.random.random(1)[0]
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(10000,20000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=0
        five=0
        six=np.random.random(1)[0]
        seven=0
        eight=0
        nine=0
        ten=0
        eleven=0
        twelve=np.random.random(1)[0]
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev

    
    for i in range(20000,30000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=0
        five=np.random.random(1)[0]
        six=0
        seven=0
        eight=0
        nine=0
        ten=np.random.random(1)[0]
        eleven=0
        twelve=0
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=np.random.random(1)[0]
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    
    
    for i in range(30000,40000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=np.random.random(1)[0]
        three=np.random.random(1)[0]
        four=0
        five=0
        six=0
        seven=0
        eight=np.random.random(1)[0]
        nine=np.random.random(1)[0]
        ten=0
        eleven=0
        twelve=0
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
        
    for i in range(40000,50000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=np.random.random(1)[0]
        five=np.random.random(1)[0]
        six=0
        seven=np.random.random(1)[0]
        eight=0
        nine=np.random.random(1)[0]
        ten=0
        eleven=0
        twelve=np.random.random(1)[0]
        thirteen=np.random.random(1)[0]
        fourteen=0
        fifteen=np.random.random(1)[0]
        sixteen=0
        seventeen=np.random.random(1)[0]
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(50000,60000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=0
        five=0
        six=0
        seven=0
        eight=0
        nine=0
        ten=np.random.random(1)[0]
        eleven=0
        twelve=0
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=np.random.random(1)[0]
        seventeen=0
        eighteen=np.random.random(1)[0]
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(60000,70000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=np.random.random(1)[0]
        three=np.random.random(1)[0]
        four=0
        five=np.random.random(1)[0]
        six=0
        seven=0
        eight=np.random.random(1)[0]
        nine=np.random.random(1)[0]
        ten=np.random.random(1)[0]
        eleven=0
        twelve=0
        thirteen=0
        fourteen=0
        fifteen=np.random.random(1)[0]
        sixteen=0
        seventeen=np.random.random(1)[0]
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(70000,80000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=np.random.random(1)[0]
        five=0
        six=0
        seven=np.random.random(1)[0]
        eight=0
        nine=0
        ten=0
        eleven=np.random.random(1)[0]
        twelve=np.random.random(1)[0]
        thirteen=np.random.random(1)[0]
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    
    for i in range(80000,90000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=np.random.random(1)[0]
        four=0
        five=np.random.random(1)[0]
        six=0
        seven=np.random.random(1)[0]
        eight=0
        nine=np.random.random(1)[0]
        ten=0
        eleven=0
        twelve=0
        thirteen=np.random.random(1)[0]
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    
    for i in range(90000,100000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=np.random.random(1)[0]
        five=np.random.random(1)[0]
        six=np.random.random(1)[0]
        seven=np.random.random(1)[0]
        eight=0
        nine=0
        ten=np.random.random(1)[0]
        eleven=np.random.random(1)[0]
        twelve=np.random.random(1)[0]
        thirteen=np.random.random(1)[0]
        fourteen=np.random.random(1)[0]
        fifteen=0
        sixteen=np.random.random(1)[0]
        seventeen=np.random.random(1)[0]
        eighteen=np.random.random(1)[0]
        nineteen=np.random.random(1)[0]
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
       
    for i in range(100000,130000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=np.random.random(1)[0]
        five=0
        six=0
        seven=np.random.random(1)[0]
        eight=0
        nine=0
        ten=0
        eleven=np.random.random(1)[0]
        twelve=np.random.random(1)[0]
        thirteen=np.random.random(1)[0]
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(130000,160000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=np.random.random(1)[0]
        five=0
        six=0
        seven=0
        eight=0
        nine=0
        ten=0
        eleven=np.random.random(1)[0]
        twelve=np.random.random(1)[0]
        thirteen=np.random.random(1)[0]
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(160000,190000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=0
        five=np.random.random(1)[0]
        six=0
        seven=0
        eight=0
        nine=0
        ten=np.random.random(1)[0]
        eleven=0
        twelve=0
        thirteen=0
        fourteen=0
        fifteen=np.random.random(1)[0]
        sixteen=0
        seventeen=np.random.random(1)[0]
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(190000,210000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=np.random.random(1)[0]
        five=0
        six=0
        seven=np.random.random(1)[0]
        eight=0
        nine=0
        ten=0
        eleven=np.random.random(1)[0]
        twelve=0
        thirteen=np.random.random(1)[0]
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(210000,260000,1):
        weights=np.random.random(20)
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(260000,280000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=np.random.random(1)[0]
        four=0
        five=np.random.random(1)[0]
        six=0
        seven=0
        eight=0
        nine=np.random.random(1)[0]
        ten=np.random.random(1)[0]
        eleven=0
        twelve=0
        thirteen=0
        fourteen=0
        fifteen=np.random.random(1)[0]
        sixteen=0
        seventeen=np.random.random(1)[0]
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    
        
    for i in range(280000,300000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=0
        five=0
        six=np.random.random(1)[0]
        seven=0
        eight=0
        nine=0
        ten=0
        eleven=np.random.random(1)[0]
        twelve=0
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=np.random.random(1)[0]
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(300000,320000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=np.random.random(1)[0]
        two=np.random.random(1)[0]
        three=np.random.random(1)[0]
        four=0
        five=np.random.random(1)[0]
        six=0
        seven=0
        eight=0
        nine=np.random.random(1)[0]
        ten=0
        eleven=0
        twelve=0
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(320000,340000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=0
        four=np.random.random(1)[0]
        five=0
        six=0
        seven=0
        eight=0
        nine=0
        ten=0
        eleven=0
        twelve=np.random.random(1)[0]
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(340000,370000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=np.random.random(1)[0]
        four=0
        five=0
        six=0
        seven=np.random.random(1)[0]
        eight=0
        nine=0
        ten=0
        eleven=0
        twelve=np.random.random(1)[0]
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=np.random.random(1)[0]
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    for i in range(370000,400000,1):
        #weights = np.random.uniform(0,1,wgt)
        
        one=0
        two=0
        three=np.random.random(1)[0]
        four=0
        five=0
        six=0
        seven=0
        eight=0
        nine=0
        ten=0
        eleven=0
        twelve=np.random.random(1)[0]
        thirteen=0
        fourteen=0
        fifteen=0
        sixteen=0
        seventeen=0
        eighteen=0
        nineteen=0
        twenty=0
        weights=[one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve,thirteen,fourteen,fifteen,sixteen,seventeen,eighteen,nineteen,twenty]
        weights=np.array(weights)
        
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    
    
    return results, weights_record

# %%
returns = df.pct_change()
mean_returns = returns.mean()
cov_matrix = returns.cov()
num_portfolios = 400000
risk_free_rate = 0.015

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def test(df):
    dfData = df.cov()
    plt.subplots(figsize=(16, 16)) # 设置画面大小
    sns.heatmap(dfData, annot=True, vmax=1,vmin=-10, square=True, cmap="Blues")
    plt.savefig('./BluesStateRelation.png')
    plt.show()

# %%
test(df)

# %%
constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})

# %%
def neg_sharpe_ratio(weights, mean_returns, cov_matrix, risk_free_rate):
    p_var, p_ret = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
    return -(p_ret - risk_free_rate) / p_var

def max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix, risk_free_rate)
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bound = (0.0,1.0)
    bounds = tuple(bound for asset in range(num_assets))
    result = sco.minimize(neg_sharpe_ratio, num_assets*[1./num_assets,], args=args,
                        method='SLSQP', bounds=bounds, constraints=constraints)
    return result

# %%
def portfolio_volatility(weights, mean_returns, cov_matrix):
    return portfolio_annualised_performance(weights, mean_returns, cov_matrix)[0]

def min_variance(mean_returns, cov_matrix):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix)
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    
    bound=(0.0,1.0)
    bounds = tuple(bound for asset in range(num_assets))

    result = sco.minimize(portfolio_volatility, num_assets*[1./num_assets,], args=args, method='SLSQP', bounds=bounds, constraints=constraints)

    return result

# %%
def efficient_return(mean_returns, cov_matrix, target):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix)

    def portfolio_return(weights):
        return portfolio_annualised_performance(weights, mean_returns, cov_matrix)[1]

    constraints = ({'type': 'eq', 'fun': lambda x: portfolio_return(x) - target},
                   {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bounds = tuple((0,1) for asset in range(num_assets))
    result = sco.minimize(portfolio_volatility, num_assets*[1./num_assets,], args=args, method='SLSQP', bounds=bounds, constraints=constraints)
    return result


def efficient_frontier(mean_returns, cov_matrix, returns_range):
    efficients = []
    for ret in returns_range:
        efficients.append(efficient_return(mean_returns, cov_matrix, ret))
    return efficients

# %%
max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)

# %%
def display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate):
    results, _ = random_portfolios(num_portfolios,mean_returns, cov_matrix, risk_free_rate)
    
    max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
    sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
    max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=df.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i,5)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    max_sharpe_allocation

    min_vol = min_variance(mean_returns, cov_matrix)
    sdp_min, rp_min = portfolio_annualised_performance(min_vol['x'], mean_returns, cov_matrix)
    min_vol_allocation = pd.DataFrame(min_vol.x,index=df.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i,5)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    print("-"*80)
    print("Maximum Sharpe Ratio Portfolio Allocation\n")
    print("Annualised Return:", round(rp,2))
    print("Annualised Volatility:", round(sdp,2))
    print("\n")
    print(max_sharpe_allocation)
    print("-"*80)
    print("Minimum Volatility Portfolio Allocation\n")
    print("Annualised Return:", round(rp_min,2))
    print("Annualised Volatility:", round(sdp_min,2))
    print("\n")
    print(min_vol_allocation)
    
    plt.figure(figsize=(10, 7))
    plt.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)
    plt.colorbar()
    plt.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    plt.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')
    target = np.linspace(rp_min, 0.32, 50)
    efficient_portfolios = efficient_frontier(mean_returns, cov_matrix, target)
    plt.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
    plt.title('Calculated Portfolio Optimization based on Efficient Frontier')
    plt.xlabel('annualised volatility')
    plt.ylabel('annualised returns')
    plt.legend(labelspacing=0.8)

# %%
display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
# Out:
# --------------------------------------------------------------------------------
# Maximum Sharpe Ratio Portfolio Allocation
#
# Annualised Return: 0.28
# Annualised Volatility: 0.28
#
#
#             603993.XSHG  601601.XSHG     ...       600276.XSHG  601229.XSHG
# allocation          0.0          0.0     ...               0.0      0.52366
#
# [1 rows x 20 columns]
# --------------------------------------------------------------------------------
# Minimum Volatility Portfolio Allocation
#
# Annualised Return: -0.07
# Annualised Volatility: 0.16
#
#
#             603993.XSHG  601601.XSHG     ...       600276.XSHG  601229.XSHG
# allocation          0.0          0.0     ...           0.00648      0.08205
#
# [1 rows x 20 columns]

# %%
def display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate):
    max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
    sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
    max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=df.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    max_sharpe_allocation

    min_vol = min_variance(mean_returns, cov_matrix)
    sdp_min, rp_min = portfolio_annualised_performance(min_vol['x'], mean_returns, cov_matrix)
    min_vol_allocation = pd.DataFrame(min_vol.x,index=df.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    an_vol = np.std(returns) * np.sqrt(252)
    an_rt = mean_returns * 252
    
    print("-"*80)
    print("Maximum Sharpe Ratio Portfolio Allocation\n")
    print("Annualised Return:", round(rp,2))
    print("Annualised Volatility:", round(sdp,2))
    print("\n")
    print(max_sharpe_allocation)
    print("-"*80)
    print("Minimum Volatility Portfolio Allocation\n")
    print("Annualised Return:", round(rp_min,2))
    print("Annualised Volatility:", round(sdp_min,2))
    print("\n")
    print(min_vol_allocation)
    print("-"*80)
    print("Individual Stock Returns and Volatility\n")
    for i, txt in enumerate(df.columns):
        print (txt,":","annuaised return",round(an_rt[i],2),", annualised volatility:",round(an_vol[i],2))
    print("-"*80)
    
    fig, ax = plt.subplots(figsize=(10, 7))
    ax.scatter(an_vol,an_rt,marker='o',s=200)

    for i, txt in enumerate(df.columns):
        ax.annotate(txt, (an_vol[i],an_rt[i]), xytext=(10,0), textcoords='offset points')
    ax.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    ax.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')

    target = np.linspace(rp_min, 0.34, 50)
    efficient_portfolios = efficient_frontier(mean_returns, cov_matrix, target)
    ax.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
    ax.set_title('Portfolio Optimization with Individual Stocks')
    ax.set_xlabel('annualised volatility')
    ax.set_ylabel('annualised returns')
    ax.legend(labelspacing=0.8)

# %%
display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate)
# Out:
# --------------------------------------------------------------------------------
# Maximum Sharpe Ratio Portfolio Allocation
#
# Annualised Return: 0.28
# Annualised Volatility: 0.28
#
#
#             603993.XSHG  601601.XSHG     ...       600276.XSHG  601229.XSHG
# allocation          0.0          0.0     ...               0.0        52.37
#
# [1 rows x 20 columns]
# --------------------------------------------------------------------------------
# Minimum Volatility Portfolio Allocation
#
# Annualised Return: -0.07
# Annualised Volatility: 0.16
#
#
#             603993.XSHG  601601.XSHG     ...       600276.XSHG  601229.XSHG
# allocation          0.0          0.0     ...              0.65          8.2
#
# [1 rows x 20 columns]
# --------------------------------------------------------------------------------
# Individual Stock Returns and Volatility
#
# 603993.XSHG : annuaised return -0.48 , annualised volatility: 0.5
# ...

# %%
def display_simulated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate):
    (results, weights) = random_portfolios(num_portfolios,mean_returns, cov_matrix, risk_free_rate)
    
    max_sharpe_idx = np.argmax(results[2])
    sdp, rp = results[0,max_sharpe_idx], results[1,max_sharpe_idx]
    max_sharpe_allocation = pd.DataFrame(weights[max_sharpe_idx],index=df.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    
    min_vol_idx = np.argmin(results[0])
    sdp_min, rp_min = results[0,min_vol_idx], results[1,min_vol_idx]
    min_vol_allocation = pd.DataFrame(weights[min_vol_idx],index=df.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    print("-"*80)
    print("Maximum Sharpe Ratio Portfolio Allocation\n")
    print("Annualised Return:", round(rp,2))
    print("Annualised Volatility:", round(sdp,2))
    print("\n")
    print(max_sharpe_allocation)
    print("-"*80)
    print("Minimum Volatility Portfolio Allocation\n")
    print("Annualised Return:", round(rp_min,2))
    print("Annualised Volatility:", round(sdp_min,2))
    print("\n")
    print(min_vol_allocation)
    
    plt.figure(figsize=(10, 7))
    plt.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)
    plt.colorbar()
    plt.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    plt.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')
    plt.title('Simulated Portfolio Optimization based on Efficient Frontier')
    plt.xlabel('annualised volatility')
    plt.ylabel('annualised returns')
    plt.legend(labelspacing=0.8)

# %%
    max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
    sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
    max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=df.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i,5)for i in max_sharpe_allocation.allocation]
    #max_sharpe_allocation = max_sharpe_allocation.T
    #max_sharpe_allocation

    min_vol = min_variance(mean_returns, cov_matrix)
    sdp_min, rp_min = portfolio_annualised_performance(min_vol['x'], mean_returns, cov_matrix)
    min_vol_allocation = pd.DataFrame(min_vol.x,index=df.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i,5)for i in min_vol_allocation.allocation]
#     min_vol_allocation = min_vol_allocation.T
    
#     print("-"*80)
#     print("Maximum Sharpe Ratio Portfolio Allocation\n")
#     print("Annualised Return:", round(rp,2))
#     print("Annualised Volatility:", round(sdp,2))
#     print("\n")
#     print(max_sharpe_allocation)
#     print("-"*80)
#     print("Minimum Volatility Portfolio Allocation\n")
#     print("Annualised Return:", round(rp_min,2))
#     print("Annualised Volatility:", round(sdp_min,2))
#     print("\n")
#     print(min_vol_allocation)

# %%
min_vol_allocation
# Out:
#              allocation
# 603993.XSHG     0.00000
# 601601.XSHG     0.00000
# 601989.XSHG     0.23607
# 601988.XSHG     0.00000
# 601939.XSHG     0.00000
# 601888.XSHG     0.02514
# 601857.XSHG     0.06806
# 601800.XSHG     0.00000
# 601766.XSHG     0.00000
# 600031.XSHG     0.00000
# 601288.XSHG     0.00000
# 601328.XSHG     0.58221
# 601818.XSHG     0.00000
# 601688.XSHG     0.00000
# 600036.XSHG     0.00000
# 601186.XSHG     0.00000
# 600028.XSHG     0.00000
# 600585.XSHG     0.00000
# 600276.XSHG     0.00648
# 601229.XSHG     0.08205

# %%
sdp
# Out:
# 0.28109414362016133
